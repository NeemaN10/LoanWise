# %%
from flask import Flask, request, jsonify, render_template
import joblib

app = Flask(__name__)

# Load your trained model here
model = joblib.load('model/loan_status_predict.pkl')

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/index.html')
def index_html():
    return render_template('index.html')

@app.route('/loan-prediction.html')
def loan_prediction():
    return render_template('loan-prediction.html')

@app.route('/predict', methods=['POST'])
def predict():
    # Get form data
    Gender = int(request.form['Gender'])
    Married = int(request.form['Married'])
    Dependents = int(request.form['Dependents'])
    Education = int(request.form['Education'])
    Self_Employed = int(request.form['Self_Employed'])
    ApplicantIncome = float(request.form['ApplicantIncome'])
    CoapplicantIncome = float(request.form['CoapplicantIncome'])
    LoanAmount = float(request.form['LoanAmount'])
    Loan_Amount_Term = float(request.form['Loan_Amount_Term'])
    Credit_History = int(request.form['Credit_History'])
    Property_Area = int(request.form['Property_Area'])

    # Make prediction
    prediction = model.predict([[Gender, Married, Dependents, Education, Self_Employed,
                                 ApplicantIncome, CoapplicantIncome, LoanAmount,
                                 Loan_Amount_Term, Credit_History, Property_Area]])

    # Determine prediction result
    if prediction[0] == 1:
        prediction_result = 'Eligible for Loan'
    else:
        prediction_result = 'Not Eligible for Loan'

    # Render the prediction result on the same page
    return render_template('loan-prediction.html', prediction_result=prediction_result)

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [12/Aug/2024 19:56:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 19:56:55] "GET /styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 19:56:56] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 19:57:01] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 19:57:01] "GET /styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 19:57:42] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:01:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:01:28] "GET /styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:01:31] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:01:32] "GET /static/styles.css HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:02:11] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:03:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:03:02] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:03:11] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:03:11] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:03:13] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:03:49] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:03:50] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:03:51] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:03:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:03:55] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:03:56] "GET /img.jpeg HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:04:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:04:42] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:04:42] "GET /static/img.jpeg HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:05:36] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:05:36] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:10:17] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:10:17] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:10:20] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:10:26] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:10:26] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:10:28] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:10:28] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:10:29] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:19:03] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:19:03] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:19:11] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:22:22] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:22:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:22:38] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:22:38] "GET /static/img.jpeg HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:22:44] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:22:45] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:22:46] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Aug/2024 20:23:58] "GET /loan-prediction.html HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Aug/2024 20:23:59] "GET /static/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/Aug/2024 20:24:00] "GET /index.html HTTP/1.1" 404 -
